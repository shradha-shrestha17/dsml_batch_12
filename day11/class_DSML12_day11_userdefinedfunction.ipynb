# %%
print("Hello","World", sep="-")
# Out:
# Hello-World

# %%
defprint("Hello","World", sep="-", end=".")
# Out:
# Hello-World.

# %%
x ="ram"
print(dir(x))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
def count_vowels(text):
  vowels = "aeiouAEIOU"
  count = 0

  for char in text:
    if char in vowels:
      count +=1
  return count

# %%
count_vowels("HElloaUjsdfjf")
# Out:
# 4

# %%
# "hello" "world"

# "hello-world"

# %%
print("Hello", "World", sep="-")
# Out:
# Hello-World

# %%
# Hello-world.
print("Hello", "World", sep="-", end=".")
# Out:
# Hello-World.

# %%
print("-------------")
print("hello world")
print("------------")
# Out:
# -------------
# hello world
# ------------

# %%
# implemetation date dd mm yyy

data1 = "hello"
data2 = "world"
print(data1,data2,sep="-")
# Out:
# hello-world

# %%
print("Hello", "World", sep="-", end="\n") #Defining Ending of line (new line)
# Out:
# Hello-World

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
# input()
name = input("waht is your name ?")
# Out:
# waht is your name ?dhiraj

# %%
#type()
type(1)
# Out:
# int

# %%
type(4==2)
# Out:
# bool

# %%
#len()
lst = [1,2,3,4,5,6]
len(lst)
# Out:
# 6

# %%
# dir()
x = "ram"
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
# open()
file = open("dummy_log.txt", mode ="r")
print(file.read())
# Out:
# [2026-07-16 10:27:24] [INFO] Connection timeout while reaching database.
# [2026-07-16 10:28:24] [DEBUG] Cache flushing completed successfully.
# [2026-07-16 10:29:24] [DEBUG] Connection timeout while reaching database.
# [2026-07-16 10:30:24] [WARNING] Failed to load resource: 404 Not Found.
# [2026-07-16 10:31:24] [INFO] Connection timeout while reaching database.
# [2026-07-16 10:32:24] [WARNING] User authentication successful.
# [2026-07-16 10:33:24] [ERROR] Connection timeout while reaching database.
# [2026-07-16 10:34:24] [WARNING] Cache flushing completed successfully.
# [2026-07-16 10:35:24] [WARNING] API request completed in 142ms.
# [2026-07-16 10:36:24] [DEBUG] Disk space reaching 88% capacity.
# [2026-07-16 10:37:24] [ERROR] User authentication successful.
# [2026-07-16 10:38:24] [WARNING] Connection timeout while reaching database.
# [2026-07-16 10:39:24] [INFO] Connection timeout while reaching database.
# [2026-07-16 10:40:24] [ERROR] API request completed in 142ms.
# ...

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1041/1407933502.py in <cell line: 0>()
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
# file = open("dummy_log.txt", mode = "a")
# file.write("Hello DSML Course ")
# Out:
# 18

# %%
with open("/content/dummy_log.txt", mode = "r+") as file:
  file.seek(0) #move pointer to a beginning
  file.write("messi")
  print(file.read())
# Out:
# jDSML CourseHello DSML CourseHello DSML Course
# Hello DSML Course dhiraj

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
lst = [1,20,3,4,5,6]
#enumerate
for index, num in enumerate(lst):
  # print(f"{num}")
  print(num)
# Out:
# 1
# 20
# 3
# 4
# 5
# 6

# %%
names = ["Rame", "shyam", "Hari", "gita"]
for (i,name) in enumerate(names):
  print(f"{name}:Roll {i}")
# Out:
# Rame:Roll 0
# shyam:Roll 1
# Hari:Roll 2
# gita:Roll 3

# %%
names = ("Rame", "shyam", "Hari", "gita")
for (i,name) in enumerate(names, start=1):
  print(f"{name}:Roll {i}")
# Out:
# Rame:Roll 1
# shyam:Roll 2
# Hari:Roll 3
# gita:Roll 4

# %%
data1 = [1,2,3,4,5]
data2 = ["A","B","C","D","E",]

for (dat,num) in zip(data1,data2):
  print(dat,num, sep="->")
# Out:
# 1->A
# 2->B
# 3->C
# 4->D
# 5->E
