# %% [markdown]
# actual ma cha, check garda dekhyo pani - true positive
#
#
# actual ma chaina , check garda ni chaina- true negative
#
# actual ma false cha , model shows positive = false positive
#
# actual ma covid cha true, model shows negative = false negative

# %% [markdown]
# Accuracy- TP, TN

# %% [markdown]
# Accuracy - correct thau ma mileko / total

# %% [markdown]
# Precision wrt apple = apple ma coorect bhako / total in apple

# %% [markdown]
# recall = total correct place / total number of that item

# %% [markdown]
# Precision

# %%
TP = 50
FP = 15
FN = 10
TN = 25

# %%
precision = TP/(TP + FP)
precision
# Out:
# 0.7692307692307693

# %%
recall = TP/(TP + FN)
recall
# Out:
# 0.8333333333333334

# %%
f1_score = 2*precision*recall/(precision + recall)
f1_score
# Out:
# 0.8

# %%
accuracy = (TP + TN)/(TP + TN + FP + FN)
accuracy
# Out:
# 0.75

# %% [markdown]
# # 1. A machine learning model is used to detect whether an email is spam or not. Out of 1,000 emails, the model correctly classifies 950 emails. Which metric measures this overall correctness?
#
# # A. Precision
# # B. Recall
# # C. Accuracy
# # D. F1 Score

# %%
#Accuracy

# %% [markdown]
# # 2. A fraud detection system flags 100 transactions as fraudulent, but only 80 of them are actually fraudulent. Which metric measures how many of the flagged transactions were actually fraud?
#
# # A. Accuracy
# # B. Precision
# # C. Recall
# # D. F1 Score
#
# Correct : Precison

# %% [markdown]
# # 3. A medical screening model needs to identify as many patients with a disease as possible. Which metric should be prioritized?
#
# # A. Accuracy
# # B. Precision
# # C. Recall
# # D. F1 Score
#
# Correct: Recall

# %% [markdown]
# # 4. A model has high precision but low recall. What does this mean?
#
# # A. It identifies most positive cases but makes many false positive predictions
# # B. Most of its positive predictions are correct, but it misses many actual positive cases
# # C. It makes both false positives and false negatives equally
# # D. It correctly predicts almost every observation
#
#
# Correct - B

# %% [markdown]
# # 5. Which metric provides a balance between precision and recall by calculating their harmonic mean?
#
# # A. Accuracy
# # B. Precision
# # C. Recall
# # D. F1 Score
#
# Correct : F1 Score

# %% [markdown]
# # 6. A dataset contains 95% healthy patients and only 5% patients with a disease. A model predicts every patient as healthy and achieves 95% accuracy. Why might accuracy be misleading?
#
# # A. Accuracy cannot be calculated for classification
# # B. The model has correctly identified all diseased patients
# # C. The high accuracy comes mainly from correctly predicting the majority class
# # D. Accuracy is always lower than precision
#
# Correct : C

# %% [markdown]
# # 7. In a cancer detection system, which situation makes recall more important than precision?
#
# # A. When false positives are very costly
# # B. When missing a patient with cancer is very dangerous
# # C. When the dataset is perfectly balanced
# # D. When computational speed is the main concern
#
# Correct B

# %% [markdown]
# # 8. In a spam filter, which situation makes precision particularly important?
#
# # A. When missing spam emails is the only concern
# # B. When incorrectly marking legitimate emails as spam is costly
# # C. When the dataset contains equal numbers of spam and legitimate emails
# # D. When recall is always zero
#
#
# Correct B

# %% [markdown]
# | Scenario                         | Priority                                 | Metric                  |
# | -------------------------------- | ---------------------------------------- | ----------------------- |
# | Student pass/fail, balanced data | Overall correctness                      | **Accuracy**            |
# | Spam email                       | Don't mark normal emails as spam         | **Precision**           |
# | Cancer detection                 | Don't miss sick patients                 | **Recall**              |
# | Fraud detection                  | Find fraud + avoid false alarms          | **F1 Score**            |
# | Airport security                 | Don't miss threats                       | **Recall**              |
# | Search engine results            | Relevant results among retrieved results | **Precision**           |
# | Cybersecurity attack detection   | Don't miss attacks                       | **Recall**              |
# | Face recognition access system   | Avoid wrongly identifying someone        | **Precision**           |
# | Imbalanced dataset               | Accuracy may be misleading               | **Precision/Recall/F1** |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
